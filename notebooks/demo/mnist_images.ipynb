# %%
import tensorwatch as tw

# %%
samples = tw.open("top(l, out_xform=pyt_img_class_out_xform, order='rnd')", event_name='batch', throttle=3, type='image')
samples.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999702750873">
