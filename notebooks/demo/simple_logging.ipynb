# %%
import tensorwatch as tw

# %%
text = tw.open()
text.show()

# %%
graph = tw.open(type='line')
graph.show()
# Out:
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)'},
#               'mode': 'lin…

# %%
summary = tw.open(type='summary', cell=graph.cell)

# %%
mpl_graph = tw.open(type='mpl-line')
mpl_graph.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
rsum = tw.open('lambda v:v.rsum', type='mpl-line')
rsum.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
rsum3d = tw.open('lambda v:(v.i, v.sum, v.rsum)', type='line3d')
rsum3d.show()
# Out:
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)'},
#               'mode': 'lin…
