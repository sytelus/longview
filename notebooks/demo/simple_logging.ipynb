# %%
# %matplotlib notebook
import tensorwatch as tw

# %%
text = tw.create_vis()
text.show()

# %%
graph = tw.create_vis(type='line')
graph.show()
# Out:
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)'},
#               'mode': 'lin…

# %%
summary = tw.create_vis(type='summary', cell=graph.cell)

# %%
mpl_graph = tw.create_vis(type='mpl-line')
mpl_graph.show()
# Out:
# <img src="data:image/png;base64,..." width="799.3651156666974">
# ...
