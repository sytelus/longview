# %%
import tensorwatch as tw

# %%
r = tw.open()

# %%
r.show()

# %%
r2 = tw.open(type='line')
r2.show()
# Out:
# ...
#     'data': [{'line': {'color': 'rgb(31, 119, 180)'},
#               'mode': 'lin…

# %%
r3 = tw.open(type='mpl-line')
r3.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999702750873">
