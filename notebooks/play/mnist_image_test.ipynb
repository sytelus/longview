# %%
# %matplotlib notebook
import tensorwatch as tw

# %%
samples = tw.open("top(l, out_xform=pyt_img_class_out_xform, order='rnd')", event_name='batch', type='image', throttle=1)
samples.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),), layout=Layout(height='4in', width='100%'))

# %%
# import matplotlib.pyplot as plt
# img = samples._stream_plots['c0062681-96c5-479f-8efb-ef7f741c41bf'].imgs[0][0]
# plt.imshow(img, cmap='gray')
samples.last_updated
# Out:
# 1554630488.9156077

# %%
samples.last_ex

# %%
samples._stream_plots
# Out:
# {'ba77eee5-0a89-44b7-b909-5a08f403696f': <tensorwatch.lv_types.StreamPlot at 0x2329e39b6a0>}

# %%
# grads = tw.open('lambda d:agg_params(d.model, lambda p: p.grad.abs().mean().item())', event_name='batch', throttle=1,
#                title="Weight Gradients",  xtitle='Epoch', ytitle='Gradients', clear_after_each=True, type='mpl-line',
#                clear_after_end=False, history_len=20)
# grads.show()

# %%
# grads2 = tw.open('lambda d:agg_params(d.model, lambda p: p.grad.abs().mean().item())', event_name='batch', throttle=1,
#                title="Weight Gradients",  xtitle='Epoch', ytitle='Gradients', clear_after_each=True, type='mpl-line',
#                clear_after_end=False, history_len=20)
# grads2.show()
