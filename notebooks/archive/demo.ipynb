# %%
# %matplotlib notebook

import add_parent_path
import tensorwatch as tw

# %%
cli = tw.WatchClient()

# %%
s = cli.create_stream("LossEvent", 'map(lambda v:math.sqrt(v.loss), l)')
r = tw.ScatterPlotRenderer()
r.show(s)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s1 = cli.create_stream("Loss2Event", 'map(lambda v:math.sqrt(v.loss2), l)')
r1 = tw.ScatterPlotRenderer()
r1.show(s1)
# Out:
# <img src="data:image/png;base64,..." width="640">
