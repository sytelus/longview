# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torchvision.models
import longview as lv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
alexnet_model = torchvision.models.alexnet()
vgg16_model = torchvision.models.vgg16()

# %%
lv.draw_model(vgg16_model, [1, 3, 224, 224])
# Out:
# kind                      scopeName                                  inputs -> outputs
# onnx::Conv                VGG/Sequential[features]/Conv2d[0]         [0, 1, 2] -> [33]
# onnx::Relu                VGG/Sequential[features]/ReLU[1]           [33] -> [34]
# onnx::Conv                VGG/Sequential[features]/Conv2d[2]         [34, 3, 4] -> [35]
# onnx::Relu                VGG/Sequential[features]/ReLU[3]           [35] -> [36]
# onnx::MaxPool             VGG/Sequential[features]/MaxPool2d[4]      [36] -> [37]
# onnx::Conv                VGG/Sequential[features]/Conv2d[5]         [37, 5, 6] -> [38]
# onnx::Relu                VGG/Sequential[features]/ReLU[6]           [38] -> [39]
# onnx::Conv                VGG/Sequential[features]/Conv2d[7]         [39, 7, 8] -> [40]
# onnx::Relu                VGG/Sequential[features]/ReLU[8]           [40] -> [41]
# onnx::MaxPool             VGG/Sequential[features]/MaxPool2d[9]      [41] -> [42]
# onnx::Conv                VGG/Sequential[features]/Conv2d[10]        [42, 9, 10] -> [43]
# onnx::Relu                VGG/Sequential[features]/ReLU[11]          [43] -> [44]
# onnx::Conv                VGG/Sequential[features]/Conv2d[12]        [44, 11, 12] -> [45]
# onnx::Relu                VGG/Sequential[features]/ReLU[13]          [45] -> [46]
# onnx::Conv                VGG/Sequential[features]/Conv2d[14]        [46, 13, 14] -> [47]
# onnx::Relu                VGG/Sequential[features]/ReLU[15]          [47] -> [48]
# onnx::MaxPool             VGG/Sequential[features]/MaxPool2d[16]     [48] -> [49]
# onnx::Conv                VGG/Sequential[features]/Conv2d[17]        [49, 15, 16] -> [50]
# onnx::Relu                VGG/Sequential[features]/ReLU[18]          [50] -> [51]
# onnx::Conv                VGG/Sequential[features]/Conv2d[19]        [51, 17, 18] -> [52]
# onnx::Relu                VGG/Sequential[features]/ReLU[20]          [52] -> [53]
# onnx::Conv                VGG/Sequential[features]/Conv2d[21]        [53, 19, 20] -> [54]
# onnx::Relu                VGG/Sequential[features]/ReLU[22]          [54] -> [55]
# onnx::MaxPool             VGG/Sequential[features]/MaxPool2d[23]     [55] -> [56]
# onnx::Conv                VGG/Sequential[features]/Conv2d[24]        [56, 21, 22] -> [57]
# onnx::Relu                VGG/Sequential[features]/ReLU[25]          [57] -> [58]
# onnx::Conv                VGG/Sequential[features]/Conv2d[26]        [58, 23, 24] -> [59]
# onnx::Relu                VGG/Sequential[features]/ReLU[27]          [59] -> [60]
# onnx::Conv                VGG/Sequential[features]/Conv2d[28]        [60, 25, 26] -> [61]
# onnx::Relu                VGG/Sequential[features]/ReLU[29]          [61] -> [62]
# onnx::MaxPool             VGG/Sequential[features]/MaxPool2d[30]     [62] -> [63]
# onnx::Constant            VGG                                        [] -> [64]
# onnx::Shape               VGG                                        [63] -> [65]
# onnx::Gather              VGG                                        [65, 64] -> [66]
# onnx::Constant            VGG                                        [] -> [67]
# onnx::Unsqueeze                                                      [66] -> [68]
# onnx::Unsqueeze                                                      [67] -> [69]
# onnx::Concat                                                         [68, 69] -> [70]
# onnx::Reshape             VGG                                        [63, 70] -> [71]
# onnx::Gemm                VGG/Sequential[classifier]/Linear[0]       [71, 27, 28] -> [72]
# onnx::Relu                VGG/Sequential[classifier]/ReLU[1]         [72] -> [73]
# onnx::Dropout             VGG/Sequential[classifier]/Dropout[2]      [73] -> [74, 75]
# onnx::Gemm                VGG/Sequential[classifier]/Dropout[2]      [74, 29, 30] -> [76]
# onnx::Relu                VGG/Sequential[classifier]/ReLU[4]         [76] -> [77]
# onnx::Dropout             VGG/Sequential[classifier]/Dropout[5]      [77] -> [78, 79]
# onnx::Gemm                VGG/Sequential[classifier]/Dropout[5]      [78, 31, 32] -> [80]

# %%
isinstance(torch.zeros([1, 3, 224, 224]), torch.Tensor)
# Out:
# True
